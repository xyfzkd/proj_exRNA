# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
proj_exRNA_read = '/home/xieyufeng/proj_exRNA/stat/proj_exRNA.readsN.stat.txt'

# %%
read_type = pd.read_table(proj_exRNA_read)
print(read_type)
# Out:
#               cleanN   rRNAN     keptN   miRNAN  de_miRNAN   piRNAN  \
# Sample_N13   9832563  152265   9680298  2679034    7001264  2756271
# Sample_N19   9672552  156809   9515743  2500240    7015503  2984603
# Sample_N1   11181350  236523  10944827  2859246    8085581  3872119
# Sample_N25  11199637  226446  10973191  1993941    8979250  4806084
# Sample_N7    9460864  256894   9203970  2315973    6887997  2908347
#
#             de_piRNAN  Y_RNAN  de_Y_RNAN  srpRNAN      ...        snoRNAN  \
# Sample_N13    4244993  233643    4011350     4218      ...           2165
# Sample_N19    4030900  162876    3868024     6107      ...           2308
# Sample_N1     4213462  177650    4035812     6143      ...           3613
# Sample_N25    4173166   88520    4084646     5670      ...           2578
# Sample_N7     3979650  190459    3789191     6194      ...           2977
#
#             de_snoRNAN  lncRNAN  de_lncRNAN  mRNAN  de_mRNAN   tucpN  \
# ...

# %%
read_type['rRNA_ratio'] = read_type['rRNAN']/read_type['cleanN']
read_type['miRNA_ratio'] = read_type['miRNAN']/read_type['cleanN']
read_type['piRNA_ratio'] = read_type['piRNAN']/read_type['cleanN']
read_type['Y_RNA_ratio'] = read_type['Y_RNAN']/read_type['cleanN']
read_type['srpRNA_ratio'] = read_type['srpRNAN']/read_type['cleanN']
read_type['tRNA_ratio'] = read_type['tRNAN']/read_type['cleanN']
read_type['snRNA_ratio'] = read_type['snRNAN']/read_type['cleanN']
read_type['snoRNA_ratio'] = read_type['snoRNAN']/read_type['cleanN']
read_type['lncRNA_ratio'] = read_type['lncRNAN']/read_type['cleanN']
read_type['mRNA_ratio'] = read_type['mRNAN']/read_type['cleanN']
read_type['tucp_ratio'] = read_type['tucpN']/read_type['cleanN']
read_type['hg38other_ratio'] = read_type['hg38otherN']/read_type['cleanN']
read_type['other_ratio'] = read_type['de_hg38otherN']/read_type['cleanN']
rnanames = ['rRNA','miRNA','piRNA','Y_RNA','srpRNA','snRNA','snoRNA','lncRNA','mRNA','tucp','hg38other','other']
read_type
# Out:
#               cleanN   rRNAN     keptN   miRNAN  de_miRNAN   piRNAN  \
# Sample_N13   9832563  152265   9680298  2679034    7001264  2756271
# Sample_N19   9672552  156809   9515743  2500240    7015503  2984603
# Sample_N1   11181350  236523  10944827  2859246    8085581  3872119
# Sample_N25  11199637  226446  10973191  1993941    8979250  4806084
# Sample_N7    9460864  256894   9203970  2315973    6887997  2908347
#
#             de_piRNAN  Y_RNAN  de_Y_RNAN  srpRNAN     ...      Y_RNA_ratio  \
# Sample_N13    4244993  233643    4011350     4218     ...         0.023762
# Sample_N19    4030900  162876    3868024     6107     ...         0.016839
# Sample_N1     4213462  177650    4035812     6143     ...         0.015888
# Sample_N25    4173166   88520    4084646     5670     ...         0.007904
# Sample_N7     3979650  190459    3789191     6194     ...         0.020131
#
#             srpRNA_ratio  snRNA_ratio  snoRNA_ratio  lncRNA_ratio  mRNA_ratio  \
# ...

# %%
read_type_info = read_type[['rRNA_ratio','miRNA_ratio','piRNA_ratio','Y_RNA_ratio','srpRNA_ratio','tRNA_ratio','snRNA_ratio','snoRNA_ratio','lncRNA_ratio','mRNA_ratio','tucp_ratio','hg38other_ratio','other_ratio']]
read_type_info['sum']=read_type_info.apply(lambda x: x.sum(), axis=1)
read_type_info
# Out:
# /apps/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             rRNA_ratio  miRNA_ratio  piRNA_ratio  Y_RNA_ratio  srpRNA_ratio  \
# Sample_N13    0.015486     0.272465     0.280321     0.023762      0.000429
# Sample_N19    0.016212     0.258488     0.308564     0.016839      0.000631
# Sample_N1     0.021153     0.255716     0.346302     0.015888      0.000549
# Sample_N25    0.020219     0.178036     0.429129     0.007904      0.000506
# Sample_N7     0.027153     0.244795     0.307408     0.020131      0.000655
#
#             tRNA_ratio  snRNA_ratio  snoRNA_ratio  lncRNA_ratio  mRNA_ratio  \
# Sample_N13    0.029921     0.003374      0.000220      0.003009    0.005150
# ...

# %%
tableau20 = np.array([(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),  
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),  
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),  
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),  
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)])
x = rnanames
colours = tableau20[:len(x)]/255.

y = read_type_info.mean()
z = np.array([float('{:.4f}'.format(y[i])) for i in range(y.shape[0])])*100

fig1, ax1 = plt.subplots(figsize=(10,10))
patches, texts = ax1.pie(y,  colors=colours, #autopct='%1.1f%%',
                        shadow=True, startangle=90)

labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(x, z)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center', bbox_to_anchor=(1.1, .7),
           fontsize=8)
plt.title('mean distribution of each type of RNA')
##############################

y = read_type_info.iloc[0]
z = np.array([float('{:.4f}'.format(y[i])) for i in range(y.shape[0])])*100

fig1, ax1 = plt.subplots(figsize=(10,10))
patches, texts = ax1.pie(y,  colors=colours, #autopct='%1.1f%%',
                        shadow=True, startangle=90)

labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(x, z)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center', bbox_to_anchor=(1.1, .7),
           fontsize=8)
plt.title("%s's distribution of each type of RNA"%(y.name))
##############################

y = read_type_info.iloc[1]
z = np.array([float('{:.4f}'.format(y[i])) for i in range(y.shape[0])])*100

fig1, ax1 = plt.subplots(figsize=(10,10))
patches, texts = ax1.pie(y,  colors=colours, #autopct='%1.1f%%',
                        shadow=True, startangle=90)

labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(x, z)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center', bbox_to_anchor=(1.1, .7),
           fontsize=8)
plt.title("%s's distribution of each type of RNA"%(y.name))
##############################

y = read_type_info.iloc[2]
z = np.array([float('{:.4f}'.format(y[i])) for i in range(y.shape[0])])*100

fig1, ax1 = plt.subplots(figsize=(10,10))
patches, texts = ax1.pie(y,  colors=colours, #autopct='%1.1f%%',
                        shadow=True, startangle=90)

labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(x, z)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center', bbox_to_anchor=(1.1, .7),
           fontsize=8)
plt.title("%s's distribution of each type of RNA"%(y.name))
##############################

y = read_type_info.iloc[3]
z = np.array([float('{:.4f}'.format(y[i])) for i in range(y.shape[0])])*100

fig1, ax1 = plt.subplots(figsize=(10,10))
patches, texts = ax1.pie(y,  colors=colours, #autopct='%1.1f%%',
                        shadow=True, startangle=90)

labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(x, z)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center', bbox_to_anchor=(1.1, .7),
           fontsize=8)
plt.title("%s's distribution of each type of RNA"%(y.name))
##############################

y = read_type_info.iloc[4]
z = np.array([float('{:.4f}'.format(y[i])) for i in range(y.shape[0])])*100

fig1, ax1 = plt.subplots(figsize=(10,10))
patches, texts = ax1.pie(y,  colors=colours, #autopct='%1.1f%%',
                        shadow=True, startangle=90)

labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(x, z)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center', bbox_to_anchor=(1.1, .7),
           fontsize=8)
plt.title("%s's distribution of each type of RNA"%(y.name))
# Out:
# Text(0.5,1,"Sample_N7's distribution of each type of RNA")
