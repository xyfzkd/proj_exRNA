# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/home/xieyufeng/proj_exRNA/stat';
sample = ['Sample_N1', 'Sample_N7', 'Sample_N13', 'Sample_N19', 'Sample_N25'];
RNA_type = ['Y_RNA','lncRNA','mRNA','miRNA','piRNA','snRNA','snoRNA','srpRNA','tRNA','tucp'];
for i in sample:
   # print('%s_length'%i);
  #  print(str(i));
    locals()[str(i) + '_length']= pd.read_table('%s/%s.lengthN.stat.tsv'%(path, i));

# %%
Sample_N1_length
# Out:
#         sample       type  len     num
# 0    Sample_N1       rRNA   16    4569
# 1    Sample_N1       rRNA   17   13178
# 2    Sample_N1       rRNA   18    3450
# 3    Sample_N1       rRNA   19    5894
# 4    Sample_N1       rRNA   20    4298
# 5    Sample_N1       rRNA   21    5498
# 6    Sample_N1       rRNA   22    4992
# 7    Sample_N1       rRNA   23    6465
# 8    Sample_N1       rRNA   24   10387
# 9    Sample_N1       rRNA   25   15800
# 10   Sample_N1       rRNA   26    9476
# 11   Sample_N1       rRNA   27   10269
# 12   Sample_N1       rRNA   28    8454
# 13   Sample_N1       rRNA   29    8396
# 14   Sample_N1       rRNA   30    8854
# 15   Sample_N1       rRNA   31    5630
# 16   Sample_N1       rRNA   32    4375
# 17   Sample_N1       rRNA   33    4123
# 18   Sample_N1       rRNA   34    8714
# 19   Sample_N1       rRNA   35    5704
# 20   Sample_N1       rRNA   36   10515
# 21   Sample_N1       rRNA   37   21100
# 22   Sample_N1       rRNA   38   11398
# ...

# %%
Sample_N1_length[Sample_N1_length['type'] == 'Y_RNA']
# Out:
#         sample   type  len    num
# 104  Sample_N1  Y_RNA   16   1013
# 105  Sample_N1  Y_RNA   17   1399
# 106  Sample_N1  Y_RNA   18   3771
# 107  Sample_N1  Y_RNA   19   4217
# 108  Sample_N1  Y_RNA   20   3994
# 109  Sample_N1  Y_RNA   21   5007
# 110  Sample_N1  Y_RNA   22   6593
# 111  Sample_N1  Y_RNA   23  23642
# 112  Sample_N1  Y_RNA   24   1973
# 113  Sample_N1  Y_RNA   25   2041
# 114  Sample_N1  Y_RNA   26   6273
# 115  Sample_N1  Y_RNA   27   4350
# 116  Sample_N1  Y_RNA   28    793
# 117  Sample_N1  Y_RNA   29   3099
# 118  Sample_N1  Y_RNA   30   7274
# 119  Sample_N1  Y_RNA   31  75158
# 120  Sample_N1  Y_RNA   32  16371
# 121  Sample_N1  Y_RNA   33   8175
# 122  Sample_N1  Y_RNA   34    286
# 123  Sample_N1  Y_RNA   35    105
# 124  Sample_N1  Y_RNA   36   1021
# 125  Sample_N1  Y_RNA   37    157
# 126  Sample_N1  Y_RNA   38     81
# 127  Sample_N1  Y_RNA   39    173
# 128  Sample_N1  Y_RNA   40    103
# 129  Sample_N1  Y_RNA   41     17
# ...

# %%
Sample_N1 = Sample_N1_length.pivot(index='type',columns='len',values='num')
Sample_N1.fillna(0, inplace=True)
Sample_N1
# Out:
# len              16        17        18        19        20         21  \
# type
# Y_RNA        1013.0    1399.0    3771.0    4217.0    3994.0     5007.0
# hg38other  109137.0  113431.0  135487.0  154579.0  133221.0   103630.0
# lncRNA       6428.0    1464.0    4678.0    2427.0    3248.0     2884.0
# mRNA         9358.0    4156.0   20107.0    7578.0    3314.0     2079.0
# miRNA       13477.0   10031.0   25613.0  142061.0  386507.0  1273262.0
# piRNA       18180.0   15304.0   91228.0   25668.0   27165.0    20769.0
# rRNA         4569.0   13178.0    3450.0    5894.0    4298.0     5498.0
# snRNA        3071.0    4463.0   20562.0    2964.0    3520.0     3964.0
# snoRNA        150.0     205.0     315.0     301.0     415.0      451.0
# srpRNA        236.0     247.0     395.0     361.0     938.0      765.0
# tRNA        13281.0   10028.0   10899.0   14297.0   14462.0    15646.0
# tucp        17174.0    5957.0   12854.0    6956.0    9583.0     5931.0
#
# ...

# %%
for j in sample:
    for i in RNA_type:
        locals()[str(j)+'_length_' + str(i)] = locals()[str(j) + '_length'][locals()[str(j) + '_length']['type'] == str(i)];
        locals()[str(j)+'_length_' + str(i)]['ratio'] = locals()[str(j)+'_length_' + str(i)]['num']/locals()[str(j)+'_length_' + str(i)]['num'].sum()
    #locals()['Sample_N1_length_' + str(i)] = Sample_N1_length[Sample_N1_length['type'] == str(i)];
    #locals()['Sample_N1_length_' + str(i)]['ratio'] = locals()['Sample_N1_length_' + str(i)]['num']/locals()['Sample_N1_length_' + str(i)]['num'].sum()
    #print(locals()['Sample_N1_length_' + str(i)]);
# Out:
# /apps/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for j in sample:
    locals()[str(j)+'_le'] = pd.DataFrame()
    for i in RNA_type:
        append = pd.DataFrame(data = list(locals()[str(j)+'_length_' + str(i)]['num']),index = list(locals()[str(j)+'_length_' + str(i)]['len']),columns = [str(i)]);
        locals()[str(j)+'_le'][str(i)] = append[str(i)];
    #locals()[str(j)+'_le'].T.to_csv('%s/%s.length.stat.tsv'%(path, j),sep='\t')

# %%
Sample_N1_le
# Out:
#     Y_RNA  lncRNA   mRNA    miRNA    piRNA  snRNA  snoRNA  srpRNA   tRNA  \
# 16   1013    6428   9358    13477    18180   3071     150     236  13281
# 17   1399    1464   4156    10031    15304   4463     205     247  10028
# 18   3771    4678  20107    25613    91228  20562     315     395  10899
# 19   4217    2427   7578   142061    25668   2964     301     361  14297
# 20   3994    3248   3314   386507    27165   3520     415     938  14462
# 21   5007    2884   2079  1273262    20769   3964     451     765  15646
# 22   6593    4249   1124   789775    32965   3225     285     441   6808
# 23  23642    1357    873   156871    59708   2647     144     376  98074
# 24   1973     996    650    49095   124951   1167     137     383   2946
# 25   2041     893    658     4638   104226   3653     123     315  10234
# 26   6273     970    600      532    81805    560     107     276  14610
# 27   4350     988    446      258    65561    415     331     204   3348
# ...

# %%
for j in sample:
    locals()[str(j)+'_len'] = pd.DataFrame()
    for i in RNA_type:
        append = pd.DataFrame(data = list(locals()[str(j)+'_length_' + str(i)]['ratio']),index = list(locals()[str(j)+'_length_' + str(i)]['len']),columns = [str(i)]);
        locals()[str(j)+'_len'][str(i)] = append[str(i)];

# %%
Sample_N1_len
# Out:
#        Y_RNA    lncRNA      mRNA     miRNA     piRNA     snRNA    snoRNA  \
# 16  0.005702  0.159583  0.170823  0.004713  0.004695  0.054737  0.041517
# 17  0.007875  0.036346  0.075864  0.003508  0.003952  0.079547  0.056740
# 18  0.021227  0.116137  0.367037  0.008958  0.023560  0.366491  0.087185
# 19  0.023738  0.060253  0.138330  0.049685  0.006629  0.052830  0.083310
# 20  0.022482  0.080636  0.060494  0.135178  0.007016  0.062740  0.114863
# 21  0.028185  0.071599  0.037950  0.445314  0.005364  0.070653  0.124827
# 22  0.037112  0.105487  0.020518  0.276218  0.008513  0.057482  0.078882
# 23  0.133082  0.033689  0.015936  0.054864  0.015420  0.047179  0.039856
# 24  0.011106  0.024727  0.011865  0.017171  0.032269  0.020800  0.037919
# 25  0.011489  0.022170  0.012011  0.001622  0.026917  0.065110  0.034044
# 26  0.035311  0.024081  0.010953  0.000186  0.021127  0.009981  0.029615
# 27  0.024486  0.024528  0.008141  0.000090  0.016932  0.007397  0.091614
# ...

# %%
Sample_N1_len.sum()
# Out:
# Y_RNA     1.000000
# lncRNA    1.000000
# mRNA      1.000000
# miRNA     0.999998
# piRNA     0.999984
# snRNA     0.999982
# snoRNA    1.000000
# srpRNA    1.000000
# tRNA      0.999989
# tucp      1.000000
# dtype: float64

# %%
Sample_N1_le.apply(lambda x: (x/x.sum()))
# Out:
#        Y_RNA    lncRNA      mRNA     miRNA     piRNA     snRNA    snoRNA  \
# 16  0.005702  0.159583  0.170823  0.004713  0.004695  0.054738  0.041517
# 17  0.007875  0.036346  0.075864  0.003508  0.003952  0.079549  0.056740
# 18  0.021227  0.116137  0.367037  0.008958  0.023561  0.366498  0.087185
# 19  0.023738  0.060253  0.138330  0.049685  0.006629  0.052830  0.083310
# 20  0.022482  0.080636  0.060494  0.135178  0.007016  0.062741  0.114863
# 21  0.028185  0.071599  0.037950  0.445315  0.005364  0.070654  0.124827
# 22  0.037112  0.105487  0.020518  0.276219  0.008514  0.057483  0.078882
# 23  0.133082  0.033689  0.015936  0.054865  0.015420  0.047180  0.039856
# 24  0.011106  0.024727  0.011865  0.017171  0.032270  0.020801  0.037919
# 25  0.011489  0.022170  0.012011  0.001622  0.026917  0.065111  0.034044
# 26  0.035311  0.024081  0.010953  0.000186  0.021127  0.009981  0.029615
# 27  0.024486  0.024528  0.008141  0.000090  0.016932  0.007397  0.091614
# ...

# %%
tableau20 = np.array([(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),  
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),  
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),  
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),  
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)])
colours = tableau20[:len(RNA_type)]/255.
length = np.array(Sample_N1_len.T)
fig,ax=plt.subplots(11,1,figsize=(20,50))
for i in range(length.shape[0]):
    ax[i].plot(length[i],label=RNA_type[i],color=colours[i])
    ax[i].legend(loc='upper right')
    ax[i].set_xticklabels(np.arange(Sample_N1_len.index[0]-5,Sample_N1_len.index[-1],5))
